# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset

# %% [markdown]
# ## **Data Collection from Hugging Face Platform**

# %%
ds = load_dataset("amgadhasan/arabic_tweets_dialects")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/449 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet: reconstructing file:   0%|          |  0.00B / 13.3MB
# data/train-00000-of-00001.parquet: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/147725 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'dialect'],
#         num_rows: 147725
#     })
# })

# %%
ds['train'][0]
# Out:
# {'text': '@toha_Altomy @gy_yah قليلين ادب ومنافقين. لو اختهم او قريبتهم تتعاكس تقولي عليهم من نشاط حقوق المرأة من ردة فعلهم.',
#  'dialect': 'LY'}

# %%
data = [
    {
        "text": rec["text"],
        "dialect": rec["dialect"],
    }
    for rec in ds['train']
]

# %%
df = pd.DataFrame( data )
df = df.sample(frac=1, random_state=101)

# %%
df.head(5)
# Out:
#                                                      text dialect
# 70491   @Shaimaa04860379 صح كلامك الاعتدال مطلوب في كل...      EG
# 368          @heeemo1983 الصبح طفى وبعدها جا توا بلاك اوت      LY
# 88917   هي #اماني_الخياط دي كل يوم تيجي تشخط فينا وتعل...      EG
# 106083  @fadiadado196221 @ali_silia هيدا مش مبرر . نزل...      LB
# 98712   التعالى الطبقى دا بقى يضحك فشخ https://t.co/3j...      EG

# %%
print(df.shape,'\n',df.dialect.value_counts())
# Out:
# (147725, 2)
#  dialect
# EG    57636
# LY    36499
# LB    27617
# SD    14434
# MA    11539
# Name: count, dtype: int64
